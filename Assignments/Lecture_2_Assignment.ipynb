# %% [markdown]
# $\textbf{PROGRAMMING ASSIGNMENT - Lecture 2}$
# ---
#
# Instruction: Choose a dataset and perform a data storytelling, choose the proper data visualization, do not use words, your graphs must tell a story.
#
# ---
#
# Data: [Heart Disease](https://archive.ics.uci.edu/dataset/45/heart+disease)
#
# ### $\textbf{Exploring Factors Influencing Heart Disease Diagnosis: An Analysis of Clinical and Demographic Features}$

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo

# %%
heart_disease = fetch_ucirepo(id=45)
heart_disease.variables
# Out:
#         name     role  ...  units missing_values
# 0        age  Feature  ...  years             no
# 1        sex  Feature  ...   None             no
# 2         cp  Feature  ...   None             no
# 3   trestbps  Feature  ...  mm Hg             no
# 4       chol  Feature  ...  mg/dl             no
# 5        fbs  Feature  ...   None             no
# 6    restecg  Feature  ...   None             no
# 7    thalach  Feature  ...   None             no
# 8      exang  Feature  ...   None             no
# 9    oldpeak  Feature  ...   None             no
# 10     slope  Feature  ...   None             no
# 11        ca  Feature  ...   None            yes
# 12      thal  Feature  ...   None            yes
# 13       num   Target  ...   None             no
#
# [14 rows x 7 columns]

# %%
df = pd.merge(heart_disease.data.features, heart_disease.data.targets, left_index=True, right_index=True)
df.describe()
# Out:
#               age         sex          cp  ...          ca        thal         num
# count  303.000000  303.000000  303.000000  ...  299.000000  301.000000  303.000000
# mean    54.438944    0.679868    3.158416  ...    0.672241    4.734219    0.937294
# std      9.038662    0.467299    0.960126  ...    0.937438    1.939706    1.228536
# min     29.000000    0.000000    1.000000  ...    0.000000    3.000000    0.000000
# 25%     48.000000    0.000000    3.000000  ...    0.000000    3.000000    0.000000
# 50%     56.000000    1.000000    3.000000  ...    0.000000    3.000000    0.000000
# 75%     61.000000    1.000000    4.000000  ...    1.000000    7.000000    2.000000
# max     77.000000    1.000000    4.000000  ...    3.000000    7.000000    4.000000
#
# [8 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# num         0
# dtype: int64

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope   ca  thal  num
# 0   63    1   1       145   233    1  ...      0      2.3      3  0.0   6.0    0
# 1   67    1   4       160   286    0  ...      1      1.5      2  3.0   3.0    2
# 2   67    1   4       120   229    0  ...      1      2.6      2  2.0   7.0    1
# 3   37    1   3       130   250    0  ...      0      3.5      3  0.0   3.0    0
# 4   41    0   2       130   204    0  ...      0      1.4      1  0.0   3.0    0
#
# [5 rows x 14 columns]

# %%
sns.histplot(data=df, x='age', kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
sns.countplot(data=df, x='sex')
plt.title('Gender Distribution')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(data=df, x='cp')
plt.title('Chest Pain Type Distribution')
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')
plt.show()

# %%
sns.histplot(data=df, x='trestbps', kde=True)
plt.title('Resting Blood Pressure Distribution')
plt.xlabel('Resting Blood Pressure (mm Hg)')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(data=df, x='chol', kde=True)
plt.title('Serum Cholesterol Distribution')
plt.xlabel('Serum Cholesterol (mg/dl)')
plt.ylabel('Frequency')
plt.show()

# %%
sns.countplot(data=df, x='fbs')
plt.title('Fasting Blood Sugar Distribution')
plt.xlabel('Fasting Blood Sugar > 120 mg/dl')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(data=df, x='restecg')
plt.title('Resting Electrocardiographic Results Distribution')
plt.xlabel('Resting Electrocardiographic Results')
plt.ylabel('Count')
plt.show()

# %%
sns.histplot(data=df, x='thalach', kde=True)
plt.title('Maximum Heart Rate Achieved Distribution')
plt.xlabel('Maximum Heart Rate Achieved')
plt.ylabel('Frequency')
plt.show()

# %%
sns.countplot(data=df, x='exang')
plt.title('Exercise Induced Angina Distribution')
plt.xlabel('Exercise Induced Angina')
plt.ylabel('Count')
plt.show()

# %%
sns.histplot(data=df, x='oldpeak', kde=True)
plt.title('ST Depression Induced by Exercise Distribution')
plt.xlabel('ST Depression Induced by Exercise')
plt.ylabel('Frequency')
plt.show()

# %%
sns.countplot(data=df, x='slope')
plt.title('Slope of the Peak Exercise ST Segment Distribution')
plt.xlabel('Slope')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(data=df, x='ca')
plt.title('Number of Major Vessels Colored by Fluoroscopy Distribution')
plt.xlabel('Number of Major Vessels')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(data=df, x='thal')
plt.title('Thalassemia Distribution')
plt.xlabel('Thalassemia')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(data=df, x='num')
plt.title('Diagnosis of Heart Disease Distribution')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.show()
